# %%
"""Parse Testudo catalog HTML into domain models."""

import re

import sys
from pathlib import Path

project_root = Path.cwd().resolve().parents[1]
sys.path.insert(0, str(project_root))

from bs4 import BeautifulSoup, Tag
from src.models import Course, Section
from typing import List

class CatalogParser:
    def parse_all_course_prefixes(self, page, tag, class_) -> List[str]:
        soup = BeautifulSoup(page, "html.parser")
        course_prefixes = soup.find_all('span', class_ = 'prefix-abbrev')

        for idx, element in enumerate(course_prefixes):
            course_prefixes[idx] = element.text

        return course_prefixes

# %%
"""HTTP client for Testudo catalog pages."""

import requests

from src.config import Settings, settings
from typing import List


class CatalogScraper:
    def __init__(self, config: Settings = settings) -> None:
        self.config = config
        self.session = requests.Session()
        self.parser = CatalogParser()
        self.session.headers["User-Agent"] = "UWA data-ingestion/1.0"

    def fetch_course_prefixes(self, semester: str) -> List[str]:
        url = f"{self.config.testudo_base_url}/{semester}"
        response = self.session.get(
            url, timeout=self.config.request_timeout_seconds
        )
        response.raise_for_status()
        course_prefixes = self.parser.parse_all_course_prefixes(response.text, 'span', 'prefix_abbrev')
        return course_prefixes

    def close(self) -> None:
        self.session.close()

    def __enter__(self) -> "CatalogScraper":
        return self

    def __exit__(self, *_: object) -> None:
        self.close()

payload = {
    "courseId": "CMSC",
    "sectionId": "",
    "termId": "202608",

    "_openSectionsOnly": "on",

    "creditCompare": ">=",
    "credits": "0.0",
    "courseLevelFilter": "ALL",
    "instructor": "",

    "_facetoface": "on",
    "_blended": "on",
    "_online": "on",

    "courseStartCompare": "",
    "courseStartHour": "",
    "courseStartMin": "",
    "courseStartAM": "",

    "courseEndHour": "",
    "courseEndMin": "",
    "courseEndAM": "",

    "teachingCenter": "ALL",

    "_classDay1": "on",
    "_classDay2": "on",
    "_classDay3": "on",
    "_classDay4": "on",
    "_classDay5": "on",
}

# %%
url = "https://app.testudo.umd.edu/soc/search"

import requests

payload['courseId'] = "CMSC"
payload['termID'] = '202608'

response = requests.get(
    url, timeout=30, params = payload
)
response.raise_for_status()
soup = BeautifulSoup(response.text, "html.parser")

# %%
unparsed_courses = soup.find_all("div", class_="course")
unparsed_courses[0]
# Out:
# <div class="course" id="CMSC100">
# <input name="courseId" type="hidden" value="CMSC100"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">CMSC100</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">Bits and Bytes of Computer and Information Sciences</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(0)</span>
# <input name="courseId" type="hidden" value="CMSC100"/>
# </a>
# </legend>
# <div id="CMSC100-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'CMSC100', '*', '/soc');" title="Add to My Saved List">
# <img alt="Add to My Saved List" src="/soc/resources/images/unsaved-star.png"/>
# </a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# <div class="course-credits-group two columns">
# <div>
# <span class="course-info-label">Credits:</span>
# <span class="course-min-credits">1</span>
# </div>
# </div>
# <div class="grading-method-group five columns">
# <div>
# <span class="course-info-label"><abbr title="Grading Method"><span>Grad Meth</span></abbr></span>:
# 														<span class="grading-method">
# <abbr title="Regular"><span>Reg</span></abbr>
# </span>
# </div>
# </div>
# <div class="gen-ed-codes-group six columns">
# <div>
# </div>
# </div>
# </div>
# </div>
# <div class="approved-course-texts-container">
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text"><div><div><div><strong>Restriction:</strong> For first time freshmen and first time transfer students; or permission of CMNS-Computer Science department. </div><div class="crosslisted-as"><strong>Cross-listed with:</strong> INST101. </div><div><strong>Credit only granted for:</strong> CMSC100 or INST101.</div></div></div></div>
# </div>
# </div>
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text">Students are introduced to the fields (and disciplines) of computer science and information science within a small classroom setting. They will learn to make a successful transition from high school to the university, while exploring study skills, student success plans and research opportunities.</div>
# </div>
# </div>
# </div>
# <div class="course-texts-container">
# </div>
# <div class="toggle-sections-link-container">
# <div class="row">
# <div class="sections-fieldset-container twelve columns">
# <fieldset class="sections-fieldset sections-displayed">
# <legend>
# <a class="toggle-sections-link" href="/soc/202608/CMSC/CMSC100?teachingCenter=ALL">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-s"></span><span class="toggle-sections-link-text">Hide Sections</span>
# </a>
# <span class="hidden section-deliveryFilter">
# <a class="hidden delivery-all deliveryFilter deliveryFilter--selected" href="javascript:void(0)" onclick="SocJs.showAllSections(this);">All Sections</a>
# <a class="hidden delivery-f2f deliveryFilter" href="javascript:void(0)" onclick="SocJs.showF2FSections(this);">Face-to-Face</a>
# <a class="hidden delivery-blended deliveryFilter" href="javascript:void(0)" onclick="SocJs.showBlendedSections(this);"><img alt="Blended Learning" aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/blended_icon.png" width="20px"/>  Blended Learning</a>
# <a class="hidden delivery-online deliveryFilter" href="javascript:void(0)" onclick="SocJs.showOnlineSections(this);"><img alt="Online" aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/> Online</a>
# </span>
# </legend>
# <div class="sections-container">
# <div class="sections sixteen colgrid">
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Shreya Singh</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">35</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">14</span>,
# 											</span>
# <span class="waitlist">
# <a href="https://registrar.umd.edu/registration/register-classes/waitlist-hold-file">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'CMSC100', '0101', '/soc');" title="Add to My Saved List">
# <img alt="Add to My Saved List" src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">Th</span>
# <span class="class-start-time">4:00pm</span> - <span class="class-end-time">4:50pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">CSI</span>
# <span class="class-room">2120</span></a>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0201"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0201
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Nicole Lemme</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">35</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">11</span>,
# 											</span>
# <span class="waitlist">
# <a href="https://registrar.umd.edu/registration/register-classes/waitlist-hold-file">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'CMSC100', '0201', '/soc');" title="Add to My Saved List">
# <img alt="Add to My Saved List" src="/soc/resources/images/unsaved-star.png">
# </img></a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">F</span>
# <span class="class-start-time">10:00am</span> - <span class="class-end-time">10:50am</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">IRB</span>
# <span class="class-room">1207</span></a>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0301"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0301
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Joyce Koo</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">35</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">21</span>,
# 											</span>
# <span class="waitlist">
# <a href="https://registrar.umd.edu/registration/register-classes/waitlist-hold-file">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'CMSC100', '0301', '/soc');" title="Add to My Saved List">
# <img alt="Add to My Saved List" src="/soc/resources/images/unsaved-star.png">
# </img></a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">F</span>
# <span class="class-start-time">2:00pm</span> - <span class="class-end-time">2:50pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">IRB</span>
# <span class="class-room">2207</span></a>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
def _parse_course(unparsed_course):
    course_code = unparsed_course.find('div', 'course-id')
    course_name = unparsed_course.find('div', 'course-title')
    course_credits = unparsed_course.find('div', 'course-min-credits')

    all_section_data = unparsed_course.find_all('div', 'section delivery-f2f')
    for section_data in all_section_data:
        section_id = unparsed_course.find('div', 'section-id')
        instructor = unparsed_course.find('div', 'section-instructor')
        total_seats = unparsed_course.find('div', 'total-seats-count')
        open_seats = unparsed_course.find('div', 'open-seats-count')
        section_building = unparsed_course.find('div', 'section-class-building-group push_one three columns')
        
    print(course_code)
def parse_courses(unparsed_courses):
    for course in unparsed_courses:
        _parse_course(course)

parse_courses(unparsed_courses)
# Out:
# <div class="course-id">CMSC100</div>
# <div class="course-id">CMSC106</div>
# <div class="course-id">CMSC122</div>
# <div class="course-id">CMSC125</div>
# <div class="course-id">CMSC131</div>
# <div class="course-id">CMSC132</div>
# <div class="course-id">CMSC133</div>
# <div class="course-id">CMSC216</div>
# <div class="course-id">CMSC250</div>
# <div class="course-id">CMSC320</div>
# <div class="course-id">CMSC330</div>
# <div class="course-id">CMSC335</div>
# <div class="course-id">CMSC351</div>
# <div class="course-id">CMSC388J</div>
# <div class="course-id">CMSC389A</div>
# <div class="course-id">CMSC389E</div>
# <div class="course-id">CMSC389L</div>
# <div class="course-id">CMSC389O</div>
# <div class="course-id">CMSC389P</div>
# <div class="course-id">CMSC396H</div>
# <div class="course-id">CMSC398L</div>
# <div class="course-id">CMSC398M</div>
# <div class="course-id">CMSC398N</div>
# <div class="course-id">CMSC398P</div>
# <div class="course-id">CMSC411</div>
# <div class="course-id">CMSC414</div>
# <div class="course-id">CMSC416</div>
# <div class="course-id">CMSC417</div>
# <div class="course-id">CMSC420</div>
# <div class="course-id">CMSC421</div>
# <div class="course-id">CMSC422</div>
# <div class="course-id">CMSC423</div>
# <div class="course-id">CMSC424</div>
# <div class="course-id">CMSC425</div>
# <div class="course-id">CMSC426</div>
# <div class="course-id">CMSC430</div>
# <div class="course-id">CMSC431</div>
# <div class="course-id">CMSC433</div>
# <div class="course-id">CMSC434</div>
# <div class="course-id">CMSC435</div>
# <div class="course-id">CMSC436</div>
# <div class="course-id">CMSC451</div>
# <div class="course-id">CMSC456</div>
# <div class="course-id">CMSC460</div>
# <div class="course-id">CMSC466</div>
# <div class="course-id">CMSC470</div>
# <div class="course-id">CMSC471</div>
# <div class="course-id">CMSC473</div>
# <div class="course-id">CMSC474</div>
# <div class="course-id">CMSC475</div>
# <div class="course-id">CMSC498C</div>
# <div class="course-id">CMSC498R</div>
# <div class="course-id">CMSC498Z</div>
# <div class="course-id">CMSC601</div>
# <div class="course-id">CMSC614</div>
# <div class="course-id">CMSC616</div>
# <div class="course-id">CMSC656</div>
# <div class="course-id">CMSC657</div>
# <div class="course-id">CMSC660</div>
# <div class="course-id">CMSC665</div>
# <div class="course-id">CMSC673</div>
# <div class="course-id">CMSC702</div>
# <div class="course-id">CMSC723</div>
# <div class="course-id">CMSC724</div>
# <div class="course-id">CMSC740</div>
# <div class="course-id">CMSC751</div>
# <div class="course-id">CMSC754</div>
# <div class="course-id">CMSC801</div>
# <div class="course-id">CMSC818I</div>
# <div class="course-id">CMSC818J</div>
# <div class="course-id">CMSC818V</div>
# <div class="course-id">CMSC828F</div>
# <div class="course-id">CMSC828G</div>
# <div class="course-id">CMSC829C</div>
# <div class="course-id">CMSC838B</div>
# <div class="course-id">CMSC838N</div>
# <div class="course-id">CMSC839E</div>
# <div class="course-id">CMSC848A</div>
# <div class="course-id">CMSC848B</div>
# <div class="course-id">CMSC848G</div>
# <div class="course-id">CMSC848K</div>
# <div class="course-id">CMSC848N</div>
# <div class="course-id">CMSC848P</div>
# <div class="course-id">CMSC848R</div>
# <div class="course-id">CMSC848X</div>
# <div class="course-id">CMSC848Y</div>
# <div class="course-id">CMSC858L</div>
# <div class="course-id">CMSC858N</div>

# %%
response.url
# Out:
# 'https://app.testudo.umd.edu/soc/search?courseId=CMSC&sectionId=&termId=202608&_openSectionsOnly=on&creditCompare=%3E%3D&credits=0.0&courseLevelFilter=ALL&instructor=&_facetoface=on&_blended=on&_online=on&courseStartCompare=&courseStartHour=&courseStartMin=&courseStartAM=&courseEndHour=&courseEndMin=&courseEndAM=&teachingCenter=ALL&_classDay1=on&_classDay2=on&_classDay3=on&_classDay4=on&_classDay5=on&termID=202608'
